# %%
#!/usr/bin/env python3

# Import relevant libraries to make HTTP requests and parse JSON response
import requests
import json
import csv
import io

# Set disease_id variable for triple-negative breast cancer
disease_id = "EFO_0005537"

# Build query string to get target information as well as count
query_string = """
query KnownDrugs {
  disease(efoId: "EFO_0005537") {
    id
    name
		associatedTargets (page: {size: 3, index: 0}) {
      rows{
        score
        target{
          id
          approvedName
          approvedSymbol
          knownDrugs{
            rows{
              drug{
                name
                id
              }
            }
          }
        }
      }
    }
}
}
"""

# Set variables object of arguments to be passed to endpoint
variables = {"efoId": disease_id}

# Set base URL of GraphQL API endpoint
base_url = "https://api.platform.opentargets.org/api/v4/graphql"

# Perform POST request and check status code of response
r = requests.post(base_url, json={"query": query_string, "variables": variables})
print(r.status_code)

#Transform API response from JSON into Python dictionary and print in console
api_response = json.loads(r.text)
print('done')
#print(api_response)
# Out:
# 200
# done

# %%
a=0
#create list of target IDs by calling them from dictionary
target_ids = api_response['data']['disease']['associatedTargets']['rows']
#print(target_ids)
target_id_list = []
#pull IDs from dictionary and add to new list
while a < len(target_ids):
    target_id_list.append(target_ids[a]['target'].get('id'))
    a+=1
print(target_id_list)
# Out:
# ['ENSG00000184292', 'ENSG00000198900', 'ENSG00000120217']

# %%
#Create new dictionary assigning assays to to each target, and assigning compounds to each assay using PUG REST
# Able to write dictionary at a speed of 4 targets/second

a=0
target_id_assay_dict = {}
for target_id in target_id_list:
# get raw AIDs (Assay IDs) for each Ensemble ID in JSON format using PUG REST
    r = requests.get('https://pubchem.ncbi.nlm.nih.gov/rest/pug/gene/synonym/Ensemble:' + target_id + '/aids/json')
# convert JSON to Python Dictionary
    raw_aids = r.json()
    #print(type(raw_aids))
# isolate raw_aids into a list containing just the AIDs from the dictionary
    try:
        aids = raw_aids['InformationList']['Information'][0]['AID']
    except:
        pass
# assign each Ensamble Target ID to dictionary entry with associated Assay IDs
    #target_id_assay_dict[id] =  aids
        
    #create sub-dictionary for compounds within each assay
    target_id_assay_dict[target_id] =  {}
    for aid in aids:
        aid = str(aid)
        print(aid)
        #get raw CIDS (Compound IDs) for each Assay in JSON format using PUG REST
        r = requests.get('https://pubchem.ncbi.nlm.nih.gov/assay/pcget.cgi?query=download&record_type=datatable&actvty=active&response_type=display&aid=' + aid)

        loose_data = r.text

        listed_data = loose_data.split(',')
        try:   
            cid_index = listed_data.index("PUBCHEM_CID")
        except:
            continue
        #print(cid_index)
        #print(type(cid_index))

        activity_index = listed_data.index("PUBCHEM_ACTIVITY_SCORE")
        #print(activity_index)
        #print(type(activity_index))


        fhand = io.StringIO(loose_data)

        cids_with_activities = []
        
        for line in fhand:
            line = line.split(',')
    
            while ('' in line):
                line.remove('')
            try:
                int(line[0])
                int(line[cid_index])
                float(line[activity_index])
            except:
                line = ""
                continue
            cid_with_activity = (line[cid_index], line[activity_index])
            cids_with_activities.append(cid_with_activity)
        #isolate raw_cids into a list containing just the CIDs from the dictionary
        if len(cids_with_activities) > 0:
            #assign CIDs to associated AID dictionary entry
            target_id_assay_dict[target_id][aid] = cids_with_activities
            print("Compounds found! Adding compounds to dictionary and passing to next assay.")
        else:
            print("No compounds found for assay. Passing to next assay.")
            continue
        
    a+=1
    display(a)
print(target_id_assay_dict)
# Out:
# 1904
# No compounds found for assay. Passing to next assay.
# 624099
# No compounds found for assay. Passing to next assay.
# 651810
# No compounds found for assay. Passing to next assay.
# 651811
# No compounds found for assay. Passing to next assay.
# 743121
# No compounds found for assay. Passing to next assay.
# 743454
# No compounds found for assay. Passing to next assay.
# 1117281
# No compounds found for assay. Passing to next assay.
# 1117357
# 1159506
# 1159578
# No compounds found for assay. Passing to next assay.
# 1159584
# No compounds found for assay. Passing to next assay.
# 1224830
# No compounds found for assay. Passing to next assay.
# 1346172
# No compounds found for assay. Passing to next assay.
# 1508588
# No compounds found for assay. Passing to next assay.
# 1
# 1904
# No compounds found for assay. Passing to next assay.
# 56396
# 56397
# 56398
# 56399
# 56400
# 56401
# 56402
# 56403
# 56404
# 56405
# 56406
# 56407
# 56408
# 56409
# 56410
# 56411
# 56412
# 56413
# 56414
# 56415
# 56416
# 56417
# 56418
# 56419
# 56420
# 56541
# 56542
# 56543
# 56544
# 56545
# 56546
# 56547
# 56548
# 56549
# 56550
# 56551
# 56552
# 56553
# 56554
# 56555
# 56556
# 56557
# 56558
# 56559
# 56560
# 56561
# compounds found! Adding compounds to dictionary and passing to next assay.
# 56562
# compounds found! Adding compounds to dictionary and passing to next assay.
# 56563
# compounds found! Adding compounds to dictionary and passing to next assay.
# 56564
# 56565
# 56566
# compounds found! Adding compounds to dictionary and passing to next assay.
# 56567
# compounds found! Adding compounds to dictionary and passing to next assay.
# 56568
# 56569
# 56570
# compounds found! Adding compounds to dictionary and passing to next assay.
# 56571
# compounds found! Adding compounds to dictionary and passing to next assay.
# 56572
# 56573
# compounds found! Adding compounds to dictionary and passing to next assay.
# 56574
# compounds found! Adding compounds to dictionary and passing to next assay.
# 56575
# compounds found! Adding compounds to dictionary and passing to next assay.
# 56576
# compounds found! Adding compounds to dictionary and passing to next assay.
# 56577
# 56699
# 56700
# 56701
# compounds found! Adding compounds to dictionary and passing to next assay.
# 56702
# 56703
# 56704
# 56705
# 56706
# 56707
# 56708
# No compounds found for assay. Passing to next assay.
# 56709
# 56710
# No compounds found for assay. Passing to next assay.
# 56711
# 56712
# 56713
# No compounds found for assay. Passing to next assay.
# 56714
# 56715
# 56716
# 56717
# 56718
# 56719
# 56720
# 56721
# 56722
# 56723
# 56724
# 56725
# 56726
# 56727
# 56728
# 56729
# 56730
# 56731
# 56732
# 56733
# 56864
# 56865
# 56866
# 56867
# 56868
# 56869
# 56870
# compounds found! Adding compounds to dictionary and passing to next assay.
# 56871
# 56872
# 56873
# 56874
# 56875
# 56876
# 56877
# 56878
# 56879
# 56880
# 56881
# 56882
# 56883
# compounds found! Adding compounds to dictionary and passing to next assay.
# 56884
# 56885
# 56886
# 56887
# 56888
# 56889
# 56890
# 56891
# 56892
# 56893
# 56894
# 56895
# 56896
# compounds found! Adding compounds to dictionary and passing to next assay.
# 56897
# compounds found! Adding compounds to dictionary and passing to next assay.
# 56898
# 56899
# 56900
# 56901
# 57032
# 57033
# 57034
# 57035
# 57036
# 57037
# 57038
# 57039
# 57040
# 57041
# 57042
# 57043
# 210938
# 210939
# 210940
# 210941
# compounds found! Adding compounds to dictionary and passing to next assay.
# 210942
# compounds found! Adding compounds to dictionary and passing to next assay.
# 210943
# 210944
# compounds found! Adding compounds to dictionary and passing to next assay.
# 210945
# compounds found! Adding compounds to dictionary and passing to next assay.
# 210946
# compounds found! Adding compounds to dictionary and passing to next assay.
# 210947
# compounds found! Adding compounds to dictionary and passing to next assay.
# 210948
# No compounds found for assay. Passing to next assay.
# 210949
# 211091
# 211092
# 211093
# compounds found! Adding compounds to dictionary and passing to next assay.
# 211094
# 211095
# 211097
# compounds found! Adding compounds to dictionary and passing to next assay.
# 211098
# compounds found! Adding compounds to dictionary and passing to next assay.
# 211099
# compounds found! Adding compounds to dictionary and passing to next assay.
# 211100
# compounds found! Adding compounds to dictionary and passing to next assay.
# 211101
# compounds found! Adding compounds to dictionary and passing to next assay.
# 211102
# 211103
# 211104
# 211105
# 211106
# 211107
# 211108
# 211109
# 211110
# compounds found! Adding compounds to dictionary and passing to next assay.
# 211111
# 211112
# 211113
# 211114
# 211115
# 211116
# 211117
# 224610
# compounds found! Adding compounds to dictionary and passing to next assay.
# 228425
# 228426
# compounds found! Adding compounds to dictionary and passing to next assay.
# 231982
# 232993
# 239726
# compounds found! Adding compounds to dictionary and passing to next assay.
# 239852
# 240049
# compounds found! Adding compounds to dictionary and passing to next assay.
# 240097
# compounds found! Adding compounds to dictionary and passing to next assay.
# 240620
# compounds found! Adding compounds to dictionary and passing to next assay.
# 241607
# compounds found! Adding compounds to dictionary and passing to next assay.
# 242837
# 243219
# 243220
# 243221
# 243223
# 243224
# 243225
# 243226
# 243386
# 243387
# 243388
# 243437
# 243438
# 244262
# 244263
# 244264
# 244265
# No compounds found for assay. Passing to next assay.
# 244266
# 244267
# 250096
# 251002
# compounds found! Adding compounds to dictionary and passing to next assay.
# 252286
# 252287
# 252288
# 252289
# 252290
# 252291
# 256508
# 256678
# No compounds found for assay. Passing to next assay.
# 258767
# No compounds found for assay. Passing to next assay.
# 264545
# compounds found! Adding compounds to dictionary and passing to next assay.
# 268635
# No compounds found for assay. Passing to next assay.
# 268636
# No compounds found for assay. Passing to next assay.
# 268637
# 269042
# No compounds found for assay. Passing to next assay.
# 269043
# 269110
# No compounds found for assay. Passing to next assay.
# 269203
# 283903
# 283904
# 286262
# 286403
# 286404
# 286405
# 286406
# 286407
# 286413
# 286414
# 286415
# 286416
# 286421
# 286422
# 286423
# 286424
# 286438
# 286439
# 286440
# 287709
# 287710
# No compounds found for assay. Passing to next assay.
# 287711
# No compounds found for assay. Passing to next assay.
# 287712
# No compounds found for assay. Passing to next assay.
# 293172
# compounds found! Adding compounds to dictionary and passing to next assay.
# 293480
# 293481
# 293483
# 296073
# 297066
# compounds found! Adding compounds to dictionary and passing to next assay.
# 299311
# 299312
# No compounds found for assay. Passing to next assay.
# 300366
# 300367
# 309604
# No compounds found for assay. Passing to next assay.
# 312293
# No compounds found for assay. Passing to next assay.
# 312295
# No compounds found for assay. Passing to next assay.
# 314508
# No compounds found for assay. Passing to next assay.
# 314509
# 317452
# compounds found! Adding compounds to dictionary and passing to next assay.
# 322713
# 328779
# No compounds found for assay. Passing to next assay.
# 328780
# No compounds found for assay. Passing to next assay.
# 331449
# 331828
# 333055
# 333057
# 334464
# compounds found! Adding compounds to dictionary and passing to next assay.
# 334465
# compounds found! Adding compounds to dictionary and passing to next assay.
# 334466
# No compounds found for assay. Passing to next assay.
# 336292
# 344134
# 345172
# No compounds found for assay. Passing to next assay.
# 345173
# No compounds found for assay. Passing to next assay.
# 346586
# No compounds found for assay. Passing to next assay.
# 350320
# compounds found! Adding compounds to dictionary and passing to next assay.
# 353083
# 354858
# No compounds found for assay. Passing to next assay.
# 358916
# 361234
# compounds found! Adding compounds to dictionary and passing to next assay.
# 361235
# 361236
# compounds found! Adding compounds to dictionary and passing to next assay.
# 361444
# compounds found! Adding compounds to dictionary and passing to next assay.
# 361445
# 361450
# No compounds found for assay. Passing to next assay.
# 361451
# 361452
# 362301
# compounds found! Adding compounds to dictionary and passing to next assay.
# 366208
# No compounds found for assay. Passing to next assay.
# 366217
# No compounds found for assay. Passing to next assay.
# 376730
# 377538
# No compounds found for assay. Passing to next assay.
# 378110
# 379271
# 379272
# 379273
# 379824
# 380032
# 380033
# 380253
# No compounds found for assay. Passing to next assay.
# 385404
# 389683
# 393312
# No compounds found for assay. Passing to next assay.
# 393754
# 396403
# No compounds found for assay. Passing to next assay.
# 396771
# No compounds found for assay. Passing to next assay.
# 402038
# 408919
# No compounds found for assay. Passing to next assay.
# 408920
# 408923
# No compounds found for assay. Passing to next assay.
# 409902
# 411410
# 411411
# 414753
# 418336
# compounds found! Adding compounds to dictionary and passing to next assay.
# 422411
# 422412
# 422413
# No compounds found for assay. Passing to next assay.
# 431825
# No compounds found for assay. Passing to next assay.
# 431826
# No compounds found for assay. Passing to next assay.
# 431827
# 431833
# No compounds found for assay. Passing to next assay.
# 431834
# No compounds found for assay. Passing to next assay.
# 431835
# No compounds found for assay. Passing to next assay.
# 431854
# 432397
# No compounds found for assay. Passing to next assay.
# 432398
# 432399
# No compounds found for assay. Passing to next assay.
# 432401
# No compounds found for assay. Passing to next assay.
# 432403
# No compounds found for assay. Passing to next assay.
# 432404
# No compounds found for assay. Passing to next assay.
# 433914
# 434819
# No compounds found for assay. Passing to next assay.
# 434821
# No compounds found for assay. Passing to next assay.
# 436178
# No compounds found for assay. Passing to next assay.
# 436387
# 436713
# No compounds found for assay. Passing to next assay.
# 436714
# No compounds found for assay. Passing to next assay.
# 436715
# No compounds found for assay. Passing to next assay.
# 436716
# No compounds found for assay. Passing to next assay.
# 449570
# No compounds found for assay. Passing to next assay.
# 449571
# 453108
# 453806
# No compounds found for assay. Passing to next assay.
# 456247
# 456248
# 458062
# No compounds found for assay. Passing to next assay.
# 460543
# 460544
# 462323
# 462324
# 462741
# No compounds found for assay. Passing to next assay.
# 462742
# 467763
# 467764
# 470667
# No compounds found for assay. Passing to next assay.
# 476071
# 478033
# No compounds found for assay. Passing to next assay.
# 478041
# 478056
# 480105
# 480106
# 480992
# 481164
# No compounds found for assay. Passing to next assay.
# 481165
# No compounds found for assay. Passing to next assay.
# 481166
# No compounds found for assay. Passing to next assay.
# 481167
# 481168
# No compounds found for assay. Passing to next assay.
# 481169
# No compounds found for assay. Passing to next assay.
# 481171
# 481172
# No compounds found for assay. Passing to next assay.
# 481173
# 481429
# No compounds found for assay. Passing to next assay.
# 481430
# 485536
# 486649
# No compounds found for assay. Passing to next assay.
# 487689
# No compounds found for assay. Passing to next assay.
# 487695
# 490081
# 490170
# 494546
# 497152
# No compounds found for assay. Passing to next assay.
# 497153
# No compounds found for assay. Passing to next assay.
# 511233
# 511234
# compounds found! Adding compounds to dictionary and passing to next assay.
# 527478
# No compounds found for assay. Passing to next assay.
# 527479
# No compounds found for assay. Passing to next assay.
# 536035
# No compounds found for assay. Passing to next assay.
# 536036
# No compounds found for assay. Passing to next assay.
# 536901
# 537376
# No compounds found for assay. Passing to next assay.
# 537377
# No compounds found for assay. Passing to next assay.
# 537378
# No compounds found for assay. Passing to next assay.
# 537379
# 547370
# No compounds found for assay. Passing to next assay.
# 547371
# No compounds found for assay. Passing to next assay.
# 547372
# No compounds found for assay. Passing to next assay.
# 551007
# 551009
# 551010
# No compounds found for assay. Passing to next assay.
# 551014
# 551015
# 551016
# 551263
# No compounds found for assay. Passing to next assay.
# 552714
# 565888
# No compounds found for assay. Passing to next assay.
# 565889
# No compounds found for assay. Passing to next assay.
# 565890
# No compounds found for assay. Passing to next assay.
# 577548
# No compounds found for assay. Passing to next assay.
# 577549
# No compounds found for assay. Passing to next assay.
# 577550
# No compounds found for assay. Passing to next assay.
# 578682
# No compounds found for assay. Passing to next assay.
# 578683
# No compounds found for assay. Passing to next assay.
# 590398
# No compounds found for assay. Passing to next assay.
# 591643
# No compounds found for assay. Passing to next assay.
# 591644
# 592162
# No compounds found for assay. Passing to next assay.
# 592163
# No compounds found for assay. Passing to next assay.
# 595841
# No compounds found for assay. Passing to next assay.
# 595842
# 599168
# 600204
# No compounds found for assay. Passing to next assay.
# 600208
# No compounds found for assay. Passing to next assay.
# 600209
# No compounds found for assay. Passing to next assay.
# 600210
# 600211
# 600216
# 606654
# 606747
# 607456
# compounds found! Adding compounds to dictionary and passing to next assay.
# 608854
# 608855
# 610760
# compounds found! Adding compounds to dictionary and passing to next assay.
# 611200
# No compounds found for assay. Passing to next assay.
# 611201
# No compounds found for assay. Passing to next assay.
# 612419
# No compounds found for assay. Passing to next assay.
# 612420
# No compounds found for assay. Passing to next assay.
# 615989
# 617145
# No compounds found for assay. Passing to next assay.
# 620745
# No compounds found for assay. Passing to next assay.
# 620746
# 620747
# No compounds found for assay. Passing to next assay.
# 620748
# 620749
# No compounds found for assay. Passing to next assay.
# 620798
# 620799
# No compounds found for assay. Passing to next assay.
# 624099
# No compounds found for assay. Passing to next assay.
# 632907
# compounds found! Adding compounds to dictionary and passing to next assay.
# 635424
# 636881
# 636882
# 636883
# No compounds found for assay. Passing to next assay.
# 644574
# 644575
# 644777
# 651810
# No compounds found for assay. Passing to next assay.
# 651811
# No compounds found for assay. Passing to next assay.
# 657775
# 657776
# 657777
# No compounds found for assay. Passing to next assay.
# 657778
# No compounds found for assay. Passing to next assay.
# 657779
# No compounds found for assay. Passing to next assay.
# 657780
# No compounds found for assay. Passing to next assay.
# 657781
# 657916
# No compounds found for assay. Passing to next assay.
# 657917
# No compounds found for assay. Passing to next assay.
# 657918
# No compounds found for assay. Passing to next assay.
# 666765
# No compounds found for assay. Passing to next assay.
# 673453
# 677826
# No compounds found for assay. Passing to next assay.
# 677830
# No compounds found for assay. Passing to next assay.
# 677840
# No compounds found for assay. Passing to next assay.
# 677841
# No compounds found for assay. Passing to next assay.
# 696326
# No compounds found for assay. Passing to next assay.
# 696327
# 696328
# 696329
# 696330
# No compounds found for assay. Passing to next assay.
# 699139
# 699140
# 699141
# 699143
# 699145
# 699147
# No compounds found for assay. Passing to next assay.
# 699149
# No compounds found for assay. Passing to next assay.
# 699150
# No compounds found for assay. Passing to next assay.
# 699151
# 699152
# 699153
# 699154
# No compounds found for assay. Passing to next assay.
# 699155
# No compounds found for assay. Passing to next assay.
# 699156
# No compounds found for assay. Passing to next assay.
# 699159
# No compounds found for assay. Passing to next assay.
# 701776
# No compounds found for assay. Passing to next assay.
# 701777
# No compounds found for assay. Passing to next assay.
# 702828
# No compounds found for assay. Passing to next assay.
# 702851
# No compounds found for assay. Passing to next assay.
# 702856
# No compounds found for assay. Passing to next assay.
# 702857
# No compounds found for assay. Passing to next assay.
# 704299
# 704300
# 709686
# No compounds found for assay. Passing to next assay.
# 711426
# 711429
# 714170
# compounds found! Adding compounds to dictionary and passing to next assay.
# 714171
# compounds found! Adding compounds to dictionary and passing to next assay.
# 720710
# No compounds found for assay. Passing to next assay.
# 724041
# 724051
# No compounds found for assay. Passing to next assay.
# 724052
# No compounds found for assay. Passing to next assay.
# 724053
# No compounds found for assay. Passing to next assay.
# 725344
# No compounds found for assay. Passing to next assay.
# 725345
# No compounds found for assay. Passing to next assay.
# 725730
# No compounds found for assay. Passing to next assay.
# 725731
# No compounds found for assay. Passing to next assay.
# 725732
# 725734
# 729747
# No compounds found for assay. Passing to next assay.
# 730195
# No compounds found for assay. Passing to next assay.
# 735940
# 736320
# 736814
# No compounds found for assay. Passing to next assay.
# 743121
# No compounds found for assay. Passing to next assay.
# 743454
# No compounds found for assay. Passing to next assay.
# 745329
# 746647
# 747370
# No compounds found for assay. Passing to next assay.
# 747371
# No compounds found for assay. Passing to next assay.
# 747461
# 747462
# 748349
# 749698
# No compounds found for assay. Passing to next assay.
# 756448
# 761189
# No compounds found for assay. Passing to next assay.
# 767198
# No compounds found for assay. Passing to next assay.
# 768623
# No compounds found for assay. Passing to next assay.
# 770644
# 771322
# No compounds found for assay. Passing to next assay.
# 771323
# No compounds found for assay. Passing to next assay.
# 771547
# No compounds found for assay. Passing to next assay.
# 771548
# No compounds found for assay. Passing to next assay.
# 774972
# 775817
# 775824
# No compounds found for assay. Passing to next assay.
# 776101
# 776102
# 776105
# 776106
# 776649
# No compounds found for assay. Passing to next assay.
# 776654
# 779453
# 779454
# No compounds found for assay. Passing to next assay.
# 780350
# No compounds found for assay. Passing to next assay.
# 780351
# No compounds found for assay. Passing to next assay.
# 780352
# compounds found! Adding compounds to dictionary and passing to next assay.
# 780933
# No compounds found for assay. Passing to next assay.
# 780934
# 780938
# 780939
# No compounds found for assay. Passing to next assay.
# 1061257
# No compounds found for assay. Passing to next assay.
# 1061259
# 1061261
# 1063330
# 1075781
# No compounds found for assay. Passing to next assay.
# 1075782
# No compounds found for assay. Passing to next assay.
# 1075783
# No compounds found for assay. Passing to next assay.
# 1075784
# No compounds found for assay. Passing to next assay.
# 1075785
# No compounds found for assay. Passing to next assay.
# 1075794
# No compounds found for assay. Passing to next assay.
# 1075795
# No compounds found for assay. Passing to next assay.
# 1075796
# No compounds found for assay. Passing to next assay.
# 1075797
# No compounds found for assay. Passing to next assay.
# 1075855
# No compounds found for assay. Passing to next assay.
# 1075856
# No compounds found for assay. Passing to next assay.
# 1075857
# No compounds found for assay. Passing to next assay.
# 1076036
# No compounds found for assay. Passing to next assay.
# 1076081
# No compounds found for assay. Passing to next assay.
# 1076082
# No compounds found for assay. Passing to next assay.
# 1095219
# 1095226
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1095227
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1095228
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1096583
# 1096585
# 1117281
# No compounds found for assay. Passing to next assay.
# 1117357
# 1121257
# 1122073
# 1138548
# 1142522
# No compounds found for assay. Passing to next assay.
# 1142523
# No compounds found for assay. Passing to next assay.
# 1142524
# 1142525
# No compounds found for assay. Passing to next assay.
# 1142526
# 1143108
# No compounds found for assay. Passing to next assay.
# 1143109
# No compounds found for assay. Passing to next assay.
# 1143384
# No compounds found for assay. Passing to next assay.
# 1155282
# 1155283
# 1159506
# 1159578
# No compounds found for assay. Passing to next assay.
# 1159584
# No compounds found for assay. Passing to next assay.
# 1165010
# No compounds found for assay. Passing to next assay.
# 1165011
# 1165391
# 1165392
# No compounds found for assay. Passing to next assay.
# 1165393
# No compounds found for assay. Passing to next assay.
# 1165394
# 1165395
# 1165396
# No compounds found for assay. Passing to next assay.
# 1167481
# No compounds found for assay. Passing to next assay.
# 1167482
# 1169487
# No compounds found for assay. Passing to next assay.
# 1169488
# No compounds found for assay. Passing to next assay.
# 1175659
# No compounds found for assay. Passing to next assay.
# 1175660
# 1175661
# 1175662
# 1175663
# 1175664
# 1175665
# 1179938
# 1182588
# No compounds found for assay. Passing to next assay.
# 1182589
# No compounds found for assay. Passing to next assay.
# 1182590
# 1182607
# No compounds found for assay. Passing to next assay.
# 1185511
# 1187845
# No compounds found for assay. Passing to next assay.
# 1194058
# No compounds found for assay. Passing to next assay.
# 1194769
# No compounds found for assay. Passing to next assay.
# 1194770
# No compounds found for assay. Passing to next assay.
# 1195269
# 1197367
# No compounds found for assay. Passing to next assay.
# 1197378
# 1197846
# No compounds found for assay. Passing to next assay.
# 1197849
# No compounds found for assay. Passing to next assay.
# 1198386
# No compounds found for assay. Passing to next assay.
# 1201343
# No compounds found for assay. Passing to next assay.
# 1201344
# No compounds found for assay. Passing to next assay.
# 1203574
# No compounds found for assay. Passing to next assay.
# 1203584
# 1203585
# No compounds found for assay. Passing to next assay.
# 1203586
# 1203587
# No compounds found for assay. Passing to next assay.
# 1206840
# No compounds found for assay. Passing to next assay.
# 1206841
# No compounds found for assay. Passing to next assay.
# 1206843
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1206844
# No compounds found for assay. Passing to next assay.
# 1224830
# No compounds found for assay. Passing to next assay.
# 1225979
# No compounds found for assay. Passing to next assay.
# 1226759
# 1227434
# 1227436
# 1228597
# No compounds found for assay. Passing to next assay.
# 1228598
# No compounds found for assay. Passing to next assay.
# 1228599
# No compounds found for assay. Passing to next assay.
# 1228600
# No compounds found for assay. Passing to next assay.
# 1231675
# 1231676
# 1236890
# 1236891
# 1239195
# No compounds found for assay. Passing to next assay.
# 1239196
# No compounds found for assay. Passing to next assay.
# 1239197
# No compounds found for assay. Passing to next assay.
# 1240569
# No compounds found for assay. Passing to next assay.
# 1244074
# 1244077
# No compounds found for assay. Passing to next assay.
# 1245883
# 1245884
# 1250350
# 1250351
# No compounds found for assay. Passing to next assay.
# 1250352
# No compounds found for assay. Passing to next assay.
# 1250353
# No compounds found for assay. Passing to next assay.
# 1250357
# No compounds found for assay. Passing to next assay.
# 1250358
# No compounds found for assay. Passing to next assay.
# 1250359
# No compounds found for assay. Passing to next assay.
# 1250360
# No compounds found for assay. Passing to next assay.
# 1251496
# 1251505
# No compounds found for assay. Passing to next assay.
# 1252045
# No compounds found for assay. Passing to next assay.
# 1252046
# No compounds found for assay. Passing to next assay.
# 1252049
# No compounds found for assay. Passing to next assay.
# 1252051
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1254805
# 1254806
# 1254807
# 1254810
# 1264620
# No compounds found for assay. Passing to next assay.
# 1265043
# 1268056
# No compounds found for assay. Passing to next assay.
# 1268057
# 1268058
# No compounds found for assay. Passing to next assay.
# 1269401
# No compounds found for assay. Passing to next assay.
# 1273775
# No compounds found for assay. Passing to next assay.
# 1273776
# No compounds found for assay. Passing to next assay.
# 1274490
# 1274495
# 1274535
# No compounds found for assay. Passing to next assay.
# 1274800
# No compounds found for assay. Passing to next assay.
# 1274801
# No compounds found for assay. Passing to next assay.
# 1279113
# 1284053
# 1284054
# 1284066
# No compounds found for assay. Passing to next assay.
# 1284067
# No compounds found for assay. Passing to next assay.
# 1287948
# 1287949
# 1288087
# 1288088
# 1288328
# 1288329
# 1294874
# No compounds found for assay. Passing to next assay.
# 1294922
# No compounds found for assay. Passing to next assay.
# 1302329
# 1302342
# 1306065
# 1306928
# No compounds found for assay. Passing to next assay.
# 1306930
# 1306932
# No compounds found for assay. Passing to next assay.
# 1306934
# No compounds found for assay. Passing to next assay.
# 1309918
# 1309919
# 1310522
# 1322189
# No compounds found for assay. Passing to next assay.
# 1322190
# No compounds found for assay. Passing to next assay.
# 1322191
# No compounds found for assay. Passing to next assay.
# 1324294
# No compounds found for assay. Passing to next assay.
# 1325811
# No compounds found for assay. Passing to next assay.
# 1326452
# No compounds found for assay. Passing to next assay.
# 1326609
# 1326614
# 1326622
# 1326623
# 1327275
# 1327276
# No compounds found for assay. Passing to next assay.
# 1327277
# 1327631
# No compounds found for assay. Passing to next assay.
# 1327633
# 1327805
# 1327808
# 1327956
# No compounds found for assay. Passing to next assay.
# 1333371
# No compounds found for assay. Passing to next assay.
# 1333372
# No compounds found for assay. Passing to next assay.
# 1333373
# No compounds found for assay. Passing to next assay.
# 1333374
# No compounds found for assay. Passing to next assay.
# 1337469
# 1337470
# 1337481
# 1337482
# 1337582
# 1337583
# 1339692
# 1339693
# 1346045
# No compounds found for assay. Passing to next assay.
# 1347618
# 1347619
# No compounds found for assay. Passing to next assay.
# 1347620
# No compounds found for assay. Passing to next assay.
# 1352095
# 1352096
# No compounds found for assay. Passing to next assay.
# 1358575
# 1359176
# 1361510
# No compounds found for assay. Passing to next assay.
# 1363189
# 1363190
# 1363340
# No compounds found for assay. Passing to next assay.
# 1363341
# 1363365
# 1363366
# No compounds found for assay. Passing to next assay.
# 1374093
# 1374094
# 1378651
# No compounds found for assay. Passing to next assay.
# 1382328
# No compounds found for assay. Passing to next assay.
# 1382329
# No compounds found for assay. Passing to next assay.
# 1382330
# 1382599
# 1382600
# No compounds found for assay. Passing to next assay.
# 1382607
# 1382608
# 1383386
# 1383387
# 1383388
# 1383389
# 1383390
# 1383391
# 1383392
# 1387408
# No compounds found for assay. Passing to next assay.
# 1387409
# No compounds found for assay. Passing to next assay.
# 1387410
# No compounds found for assay. Passing to next assay.
# 1387411
# No compounds found for assay. Passing to next assay.
# 1390166
# 1390167
# 1390176
# 1390177
# 1390208
# No compounds found for assay. Passing to next assay.
# 1390209
# No compounds found for assay. Passing to next assay.
# 1390210
# 1390211
# 1390212
# 1396987
# No compounds found for assay. Passing to next assay.
# 1400707
# 1400708
# 1400711
# 1401812
# 1401813
# 1401818
# 1401819
# 1401820
# 1401822
# No compounds found for assay. Passing to next assay.
# 1401823
# 1401824
# 1401825
# 1401826
# 1401830
# No compounds found for assay. Passing to next assay.
# 1401831
# No compounds found for assay. Passing to next assay.
# 1407988
# 1413829
# 1415044
# 1426110
# No compounds found for assay. Passing to next assay.
# 1426112
# No compounds found for assay. Passing to next assay.
# 1428609
# 1428613
# 1428614
# No compounds found for assay. Passing to next assay.
# 1428615
# No compounds found for assay. Passing to next assay.
# 1428616
# 1428617
# 1428618
# 1428690
# 1428691
# 1428700
# 1428701
# 1428712
# 1428713
# 1428714
# 1428715
# 1431482
# 1431483
# No compounds found for assay. Passing to next assay.
# 1442286
# 1443965
# No compounds found for assay. Passing to next assay.
# 1443966
# No compounds found for assay. Passing to next assay.
# 1443967
# No compounds found for assay. Passing to next assay.
# 1443978
# No compounds found for assay. Passing to next assay.
# 1443979
# No compounds found for assay. Passing to next assay.
# 1447300
# No compounds found for assay. Passing to next assay.
# 1447301
# No compounds found for assay. Passing to next assay.
# 1447305
# 1447306
# No compounds found for assay. Passing to next assay.
# 1447307
# No compounds found for assay. Passing to next assay.
# 1448230
# 1453061
# 1453062
# 1453394
# No compounds found for assay. Passing to next assay.
# 1457569
# No compounds found for assay. Passing to next assay.
# 1472923
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1472924
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1472925
# 1472926
# 1472927
# 1472928
# No compounds found for assay. Passing to next assay.
# 1472929
# No compounds found for assay. Passing to next assay.
# 1472930
# 1472931
# No compounds found for assay. Passing to next assay.
# 1472932
# No compounds found for assay. Passing to next assay.
# 1472933
# 1472934
# No compounds found for assay. Passing to next assay.
# 1472935
# No compounds found for assay. Passing to next assay.
# 1472936
# 1472937
# No compounds found for assay. Passing to next assay.
# 1472938
# 1472940
# No compounds found for assay. Passing to next assay.
# 1472941
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1472942
# No compounds found for assay. Passing to next assay.
# 1472947
# 1472948
# 1472950
# No compounds found for assay. Passing to next assay.
# 1472951
# No compounds found for assay. Passing to next assay.
# 1472952
# No compounds found for assay. Passing to next assay.
# 1478721
# 1478722
# 1478733
# 1478734
# 1481805
# No compounds found for assay. Passing to next assay.
# 1481806
# No compounds found for assay. Passing to next assay.
# 1481807
# No compounds found for assay. Passing to next assay.
# 1486385
# 1486759
# 1486765
# 1500678
# No compounds found for assay. Passing to next assay.
# 1500679
# No compounds found for assay. Passing to next assay.
# 1500681
# 1507687
# No compounds found for assay. Passing to next assay.
# 1507689
# 1507694
# No compounds found for assay. Passing to next assay.
# 1507695
# 1507750
# No compounds found for assay. Passing to next assay.
# 1508588
# No compounds found for assay. Passing to next assay.
# 1520397
# No compounds found for assay. Passing to next assay.
# 1520398
# No compounds found for assay. Passing to next assay.
# 1520399
# No compounds found for assay. Passing to next assay.
# 1520400
# No compounds found for assay. Passing to next assay.
# 1537211
# No compounds found for assay. Passing to next assay.
# 1544044
# 1544048
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1544049
# 1544050
# 1544057
# 1544058
# No compounds found for assay. Passing to next assay.
# 1544059
# No compounds found for assay. Passing to next assay.
# 1544060
# No compounds found for assay. Passing to next assay.
# 1544061
# No compounds found for assay. Passing to next assay.
# 1544067
# 1544068
# No compounds found for assay. Passing to next assay.
# 1544069
# 1544070
# 1544076
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1551202
# 1551203
# 1551900
# 1562002
# 1562003
# 1562010
# No compounds found for assay. Passing to next assay.
# 1562011
# No compounds found for assay. Passing to next assay.
# 1562101
# 1562102
# 1563007
# 1563008
# 1563009
# 1563013
# 1563014
# 1563015
# 1564585
# No compounds found for assay. Passing to next assay.
# 1566675
# 1566676
# 1566743
# 1566744
# No compounds found for assay. Passing to next assay.
# 1566745
# No compounds found for assay. Passing to next assay.
# 1566778
# No compounds found for assay. Passing to next assay.
# 1577582
# 1577583
# 1585186
# No compounds found for assay. Passing to next assay.
# 1585187
# No compounds found for assay. Passing to next assay.
# 1585188
# 1585189
# No compounds found for assay. Passing to next assay.
# 1585190
# 1585191
# No compounds found for assay. Passing to next assay.
# 1585192
# 1585193
# 1601654
# 1601657
# No compounds found for assay. Passing to next assay.
# 1601658
# 1601659
# No compounds found for assay. Passing to next assay.
# 1609804
# 1609821
# 1609822
# 1609823
# 1609824
# 1609825
# 1609859
# 1610469
# 1631081
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1638092
# 1638093
# 1648729
# No compounds found for assay. Passing to next assay.
# 1648730
# No compounds found for assay. Passing to next assay.
# 1648731
# No compounds found for assay. Passing to next assay.
# 1651221
# No compounds found for assay. Passing to next assay.
# 1651222
# 1651223
# 1651224
# 1651225
# 1651226
# No compounds found for assay. Passing to next assay.
# 1655966
# No compounds found for assay. Passing to next assay.
# 1655967
# No compounds found for assay. Passing to next assay.
# 1655968
# No compounds found for assay. Passing to next assay.
# 1655970
# No compounds found for assay. Passing to next assay.
# 1655971
# No compounds found for assay. Passing to next assay.
# 1655972
# No compounds found for assay. Passing to next assay.
# 1655973
# No compounds found for assay. Passing to next assay.
# 1659501
# 1659502
# 1659503
# 1667417
# No compounds found for assay. Passing to next assay.
# 1667418
# No compounds found for assay. Passing to next assay.
# 1673144
# No compounds found for assay. Passing to next assay.
# 1673146
# No compounds found for assay. Passing to next assay.
# 1673147
# No compounds found for assay. Passing to next assay.
# 1673148
# 1673149
# No compounds found for assay. Passing to next assay.
# 1673154
# No compounds found for assay. Passing to next assay.
# 1673156
# No compounds found for assay. Passing to next assay.
# 1689290
# 1689313
# No compounds found for assay. Passing to next assay.
# 1692473
# 1701969
# 1702012
# 1702822
# No compounds found for assay. Passing to next assay.
# 1702823
# 1702824
# No compounds found for assay. Passing to next assay.
# 1702825
# No compounds found for assay. Passing to next assay.
# 1702826
# No compounds found for assay. Passing to next assay.
# 1703217
# 1703218
# 1703219
# No compounds found for assay. Passing to next assay.
# 1703331
# No compounds found for assay. Passing to next assay.
# 1703332
# No compounds found for assay. Passing to next assay.
# 1708523
# No compounds found for assay. Passing to next assay.
# 1708533
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1708534
# No compounds found for assay. Passing to next assay.
# 1713804
# 1713805
# 1723562
# 1724032
# 1727988
# No compounds found for assay. Passing to next assay.
# 1727989
# No compounds found for assay. Passing to next assay.
# 1727990
# No compounds found for assay. Passing to next assay.
# 1728398
# 1728414
# 1732040
# No compounds found for assay. Passing to next assay.
# 1733013
# 1736595
# No compounds found for assay. Passing to next assay.
# 1736602
# No compounds found for assay. Passing to next assay.
# 1736603
# No compounds found for assay. Passing to next assay.
# 1736606
# No compounds found for assay. Passing to next assay.
# 1736607
# No compounds found for assay. Passing to next assay.
# 1736608
# No compounds found for assay. Passing to next assay.
# 1737446
# No compounds found for assay. Passing to next assay.
# 1737447
# No compounds found for assay. Passing to next assay.
# 1737448
# No compounds found for assay. Passing to next assay.
# 1737449
# No compounds found for assay. Passing to next assay.
# 1737450
# No compounds found for assay. Passing to next assay.
# 1738949
# No compounds found for assay. Passing to next assay.
# 1740932
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1740933
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1758341
# No compounds found for assay. Passing to next assay.
# 1758342
# No compounds found for assay. Passing to next assay.
# 1758988
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1759310
# No compounds found for assay. Passing to next assay.
# 1759311
# No compounds found for assay. Passing to next assay.
# 1759312
# No compounds found for assay. Passing to next assay.
# 1759313
# No compounds found for assay. Passing to next assay.
# 1759314
# No compounds found for assay. Passing to next assay.
# 1763576
# 1763577
# 1763578
# 1763579
# No compounds found for assay. Passing to next assay.
# 1765566
# No compounds found for assay. Passing to next assay.
# 1765569
# 1779158
# No compounds found for assay. Passing to next assay.
# 1779194
# 1779228
# 1779229
# No compounds found for assay. Passing to next assay.
# 1779298
# No compounds found for assay. Passing to next assay.
# 1781535
# No compounds found for assay. Passing to next assay.
# 1798415
# No compounds found for assay. Passing to next assay.
# 1803398
# 1808044
# No compounds found for assay. Passing to next assay.
# 1808045
# No compounds found for assay. Passing to next assay.
# 1808046
# 1808048
# No compounds found for assay. Passing to next assay.
# 1808049
# No compounds found for assay. Passing to next assay.
# 1808050
# No compounds found for assay. Passing to next assay.
# 1808110
# No compounds found for assay. Passing to next assay.
# 1810247
# 1810249
# No compounds found for assay. Passing to next assay.
# 1810251
# No compounds found for assay. Passing to next assay.
# 1810252
# No compounds found for assay. Passing to next assay.
# 1811235
# 1811236
# No compounds found for assay. Passing to next assay.
# 1817036
# No compounds found for assay. Passing to next assay.
# 1823979
# 1823980
# 1823981
# 1823982
# 1823983
# 1826593
# No compounds found for assay. Passing to next assay.
# 1826602
# No compounds found for assay. Passing to next assay.
# 1830490
# 1830496
# 2
# 1904
# No compounds found for assay. Passing to next assay.
# 624099
# No compounds found for assay. Passing to next assay.
# 651810
# No compounds found for assay. Passing to next assay.
# 651811
# No compounds found for assay. Passing to next assay.
# 743121
# No compounds found for assay. Passing to next assay.
# 743454
# No compounds found for assay. Passing to next assay.
# 1117281
# No compounds found for assay. Passing to next assay.
# 1117357
# 1159506
# 1159578
# No compounds found for assay. Passing to next assay.
# 1159584
# No compounds found for assay. Passing to next assay.
# 1224830
# No compounds found for assay. Passing to next assay.
# 1229064
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1416967
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1449577
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1449578
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1449579
# No compounds found for assay. Passing to next assay.
# 1449580
# No compounds found for assay. Passing to next assay.
# 1449581
# No compounds found for assay. Passing to next assay.
# 1449582
# No compounds found for assay. Passing to next assay.
# 1449583
# No compounds found for assay. Passing to next assay.
# 1508588
# No compounds found for assay. Passing to next assay.
# 1511283
# No compounds found for assay. Passing to next assay.
# 1511284
# No compounds found for assay. Passing to next assay.
# 1511285
# No compounds found for assay. Passing to next assay.
# 1511286
# 1511289
# No compounds found for assay. Passing to next assay.
# 1516541
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1516542
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1516543
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1516544
# 1516553
# No compounds found for assay. Passing to next assay.
# 1516554
# No compounds found for assay. Passing to next assay.
# 1533360
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1533361
# 1533364
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1533365
# 1533366
# 1533368
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1533369
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1533370
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1550033
# 1595534
# 1595535
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1595536
# 1595537
# 1624875
# 1624876
# 1624877
# 1634344
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1634345
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1634346
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1634347
# No compounds found for assay. Passing to next assay.
# 1652973
# 1652974
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1652976
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1652978
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1661026
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1661027
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1661028
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1661029
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1661030
# 1661031
# 1664443
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1675663
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1675665
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1675666
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1675668
# 1676569
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1676571
# No compounds found for assay. Passing to next assay.
# 1676572
# No compounds found for assay. Passing to next assay.
# 1676577
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1676578
# 1676579
# No compounds found for assay. Passing to next assay.
# 1676580
# No compounds found for assay. Passing to next assay.
# 1682747
# No compounds found for assay. Passing to next assay.
# 1682771
# 1682772
# 1682773
# No compounds found for assay. Passing to next assay.
# 1682774
# 1682775
# No compounds found for assay. Passing to next assay.
# 1682776
# 1682777
# 1682778
# 1682784
# No compounds found for assay. Passing to next assay.
# 1682786
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1687301
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1687303
# 1687304
# 1687305
# 1687306
# 1693863
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1693864
# No compounds found for assay. Passing to next assay.
# 1701219
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1701225
# 1701226
# 1701247
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1701249
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1701251
# No compounds found for assay. Passing to next assay.
# 1719375
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1719376
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1719377
# 1719379
# 1729336
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1729337
# 1729339
# 1729340
# 1729341
# 1729342
# 1733702
# No compounds found for assay. Passing to next assay.
# 1733703
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1733704
# No compounds found for assay. Passing to next assay.
# 1733705
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1733706
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1733707
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1733708
# 1738462
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1743868
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1743869
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1750879
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1750881
# 1750882
# 1752583
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1752584
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1752585
# 1759135
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1759136
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1760822
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1760824
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1760825
# 1760826
# 1760827
# 1769611
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1769612
# 1769613
# 1769617
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1769618
# 1769619
# 1769620
# No compounds found for assay. Passing to next assay.
# 1777325
# 1777326
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1777327
# 1777328
# No compounds found for assay. Passing to next assay.
# 1777329
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1777331
# 1777332
# No compounds found for assay. Passing to next assay.
# 1777333
# No compounds found for assay. Passing to next assay.
# 1777334
# No compounds found for assay. Passing to next assay.
# 1777335
# No compounds found for assay. Passing to next assay.
# 1777336
# No compounds found for assay. Passing to next assay.
# 1777337
# No compounds found for assay. Passing to next assay.
# 1777338
# No compounds found for assay. Passing to next assay.
# 1777339
# No compounds found for assay. Passing to next assay.
# 1777340
# No compounds found for assay. Passing to next assay.
# 1777341
# No compounds found for assay. Passing to next assay.
# 1777342
# No compounds found for assay. Passing to next assay.
# 1777343
# No compounds found for assay. Passing to next assay.
# 1782323
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1782324
# No compounds found for assay. Passing to next assay.
# 1782337
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1782343
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1796171
# No compounds found for assay. Passing to next assay.
# 1797911
# No compounds found for assay. Passing to next assay.
# 1797999
# No compounds found for assay. Passing to next assay.
# 1799052
# No compounds found for assay. Passing to next assay.
# 1803783
# No compounds found for assay. Passing to next assay.
# 1804266
# No compounds found for assay. Passing to next assay.
# 1804348
# No compounds found for assay. Passing to next assay.
# 1804377
# No compounds found for assay. Passing to next assay.
# 1804483
# No compounds found for assay. Passing to next assay.
# 1804597
# No compounds found for assay. Passing to next assay.
# 1804788
# No compounds found for assay. Passing to next assay.
# 1804789
# No compounds found for assay. Passing to next assay.
# 1804858
# No compounds found for assay. Passing to next assay.
# 1804894
# No compounds found for assay. Passing to next assay.
# 1804918
# No compounds found for assay. Passing to next assay.
# 1804919
# No compounds found for assay. Passing to next assay.
# 1804963
# No compounds found for assay. Passing to next assay.
# 1805150
# No compounds found for assay. Passing to next assay.
# 1805153
# No compounds found for assay. Passing to next assay.
# 1805207
# No compounds found for assay. Passing to next assay.
# 1805234
# No compounds found for assay. Passing to next assay.
# 1805326
# No compounds found for assay. Passing to next assay.
# 1805437
# No compounds found for assay. Passing to next assay.
# 1805502
# No compounds found for assay. Passing to next assay.
# 1805710
# No compounds found for assay. Passing to next assay.
# 1805759
# No compounds found for assay. Passing to next assay.
# 1805831
# No compounds found for assay. Passing to next assay.
# 1805934
# No compounds found for assay. Passing to next assay.
# 1805974
# No compounds found for assay. Passing to next assay.
# 1806040
# No compounds found for assay. Passing to next assay.
# 1806380
# No compounds found for assay. Passing to next assay.
# 1806550
# No compounds found for assay. Passing to next assay.
# 1806648
# No compounds found for assay. Passing to next assay.
# 1806693
# No compounds found for assay. Passing to next assay.
# 1806714
# No compounds found for assay. Passing to next assay.
# 1806736
# No compounds found for assay. Passing to next assay.
# 1806739
# No compounds found for assay. Passing to next assay.
# 1806760
# No compounds found for assay. Passing to next assay.
# 1806871
# No compounds found for assay. Passing to next assay.
# 1806875
# No compounds found for assay. Passing to next assay.
# 1806962
# No compounds found for assay. Passing to next assay.
# 1810607
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1810609
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1810616
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1810677
# 1811724
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1811725
# 1814693
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1818139
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1818140
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1818141
# 1818157
# No compounds found for assay. Passing to next assay.
# 1818158
# No compounds found for assay. Passing to next assay.
# 1818159
# 1818160
# No compounds found for assay. Passing to next assay.
# 1818171
# No compounds found for assay. Passing to next assay.
# 1818172
# No compounds found for assay. Passing to next assay.
# 1819852
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1819853
# 1826145
# 1826146
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1826147
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1826149
# No compounds found for assay. Passing to next assay.
# 1826151
# No compounds found for assay. Passing to next assay.
# 1826152
# No compounds found for assay. Passing to next assay.
# 1826153
# 1826154
# No compounds found for assay. Passing to next assay.
# 1826155
# 1826156
# 1826157
# No compounds found for assay. Passing to next assay.
# 1826158
# No compounds found for assay. Passing to next assay.
# 1826159
# No compounds found for assay. Passing to next assay.
# 1826160
# No compounds found for assay. Passing to next assay.
# 1826161
# No compounds found for assay. Passing to next assay.
# 1830587
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1830588
# compounds found! Adding compounds to dictionary and passing to next assay.
# 1830589
# compounds found! Adding compounds to dictionary and passing to next assay.
# 3
# {'ENSG00000184292': {}, 'ENSG00000198900': {'56561': [('10460355', '0.028'), ('10452851', '0.143')], '56562': [('24360', '0.82'), ('14761142', '3.4'), ('14761139', '0.4'), ('14761137', '1'), ('14761134', '0.1'), ('14761123', '0.1'), ('72402', '0.9'), ('10133241', '0.9'), ('14761129', '0.3'), ('14680467', '10'), ('97226', '1'), ('14761147', '2'), ('14680465', '0.5'), ('14761132', '0.9'), ('14761127', '0.3'), ('14761145', '1.7'), ('14761114', '0.8'), ('14761120', '0.8'), ('60700', '3.2'), ('14761164', '0.4'), ('14761163', '2'), ('14761111', '1'), ('14761117', '2.2'), ('14761156', '3'), ('14761155', '0.5'), ('14761107', '0.5'), ('14761104', '0.3'), ('14761109', '0.6'), ('104842', '0.8')], '56563': [('24360', '0.8'), ('14442798', '5'), ('23705698', '0.9')], '56566': [('10745521', '0.34'), ('10769272', '0.6'), ('10768720', '0.52'), ('10814294', '0.16'), ('11800135', '0.14'), ('10816483', '0.1'), ('9982858', '0.22'), ('10506494', '0.25'), ('10577898', '0.19'), ('10768284', '0.21')], '56567': [('60700', '1.1'), ('10600972', '0.2'), ('10097407', '0.18'), ('10626137', '0.19')], '56570': [('24360', '0.679'), ('60700', '1.028'), ('72403', '0.078'), ('468670', '0.015'), ('10366723', '0.011'), ('44352476', '0.3'), ('9874048', '0.416')], '56571': [('54686375', '10')], '56573': [('44382872', '2.1'), ('10412775', '0.7'), ('11756340', '1.3'), ('10369338', '2.3'), ('10001587', '3.2'), ('10409274', '3.1'), ('44383814', '1.9'), ('10387840', '1.5')], '56574': [('24360', '0.7'), ('9975100', '0.383'), ('44268667', '1.184'), ('10362222', '0.336'), ('10006466', '0.217'), ('10366776', '0.122'), ('44268675', '0.505'), ('10323343', '9.328'), ('10411417', '0.949'), ('10321913', '1.331'), ('9981804', '1.494'), ('11755151', '1.113'), ('10460355', '0.028'), ('10092735', '0.167'), ('10453728', '0.268'), ('10452851', '0.143'), ('60699', '1.08')], '56575': [('10319267', '0.19'), ('11756382', '1.461'), ('10482208', '0.033'), ('135437964', '0.071'), ('11741224', '0.232'), ('10252111', '1.075')], '56576': [('11742279', '1.2'), ('10000564', '5.8'), ('44383179', '1.3'), ('10455248', '1.5'), ('10364204', '1.1'), ('10091894', '4'), ('44383741', '1.8')], '56701': [('44370150', '1.45'), ('44370224', '1.61'), ('44370463', '1.59'), ('44370465', '1.14'), ('44370466', '1.44'), ('73110', '1.75'), ('10323743', '0.59')], '56870': [('22912790', '2.3'), ('21918498', '1.5')], '56883': [('10064551', '10')], '56896': [('44290602', '8.6'), ('44290621', '1.6'), ('44290683', '8.2'), ('44290796', '4.7'), ('9887873', '0.9'), ('9909579', '1.4'), ('9907879', '10'), ('10177790', '6.4'), ('10110293', '2.6')], '56897': [('9887873', '0.4')], '210941': [('24360', '0.7')], '210942': [('24360', '0.7'), ('10023217', '0.15'), ('135492582', '0.17'), ('72403', '0.03')], '210944': [('392223', '2'), ('392223', '6'), ('392223', '0.6'), ('468757', '2'), ('73110', '1.75'), ('10323743', '1.95'), ('10481621', '0.6')], '210945': [('24360', '0.01'), ('381592', '0.3'), ('15658179', '1'), ('15658193', '1'), ('15658192', '1'), ('15658189', '3')], '210946': [('24360', '0.68'), ('2538', '1.4'), ('72402', '0.11'), ('10133241', '0.038'), ('97226', '0.11'), ('14680465', '1.9'), ('60700', '1'), ('366358', '0.067'), ('72403', '0.027'), ('24878522', '0.16'), ('23666383', '0.55'), ('44324235', '4'), ('44324236', '3.8'), ('131182', '0.44'), ('13471631', '4.4'), ('44324256', '5.5'), ('44324266', '3.2'), ('18336742', '2'), ('9953190', '0.076'), ('14440698', '9.6'), ('24878308', '0.37'), ('44324330', '1'), ('135406264', '0.9'), ('15589450', '0.19'), ('9889281', '0.22'), ('44324446', '0.47'), ('494163', '1.6'), ('44324457', '3.1'), ('44324458', '0.061'), ('24878514', '0.11'), ('9932270', '0.13'), ('104986', '0.14'), ('45261054', '1.1'), ('45261084', '0.43'), ('45264950', '5.5'), ('368335', '0.57'), ('45264982', '0.26'), ('23662678', '0.84'), ('135403790', '0.87'), ('10292113', '0.3'), ('23662679', '4.3'), ('14989978', '0.15'), ('468669', '0.048'), ('9865348', '0.64'), ('10271273', '0.086'), ('10156768', '0.14')], '210947': [ ...

# %%
theDict = target_id_assay_dict

# %%
#Curate new dictionary by removing compounds that have been used in multiple assays

uniqueList = []
repeatList = []
RemovedDuplicateDict = theDict

for target in theDict:
    a=0
    print("checking target " + target + "...")
    for assay in theDict[target]:
        for compound in theDict[target][assay]:
            if compound in uniqueList:
                RemovedDuplicateDict[target][assay].remove(compound)
                if compound not in repeatList:
                    repeatList.append(compound)
            else:
                uniqueList.append(compound)   
                

#print(uniqueList)
#print("\n")
#print(repeatList)
#print(RemovedDuplicateDict)
print('done')
# Out:
# checking target ENSG00000184292...
# checking target ENSG00000198900...
# checking target ENSG00000120217...
# done

# %%
r = requests.get('https://pubchem.ncbi.nlm.nih.gov/rest/pug/assay/aid/736/sids/JSON?sids_type=active')
raw_736 = r.json()
#print(raw_736)

active_736 = raw_736['InformationList']['Information'][0]['SID']
#print(active_736)

active_736_string = str(active_736).replace(" ", "")
active_736_formatted = active_736_string[1:len(active_736_string)-1]

print(active_736_formatted)

r = requests.get('https://pubchem.ncbi.nlm.nih.gov/rest/pug/assay/aid/' + str(736) + '/concise/CSV?sid=' + active_736_formatted)
print(r)
dose_response = r.json()
print(dose_response)
# Out:
# 842204,843683,844782,846220,846490,847305,847359,848536,849093,851321,851380,852129,853296,856169,856175,856251,857318,857384,857386,857655,858283,858389,858513,858611,858637,859929,860619,861006,861727,861921,861945,861951,862684,862725,862844,863470,863640,865492,865665,865967,3711988,3712485,3713127,3714359,3716390,3717602,3717900,4240514,4241470,4242524,4244491,4244974,4247903,4248044,4249480,4251027,4251553,4254596,4255956,4257509,4259339,4261894,4263033,4265474,4265620,7966015,7966305,7969122,7970050,7972728,7978390,14718880,14720488,14720511,14720802,14720867,14721138,14721552,14722452,14723818,14723875,14724052,14724089,14725446,14725477,14725485,14725635,14726390,14726526,14727019,14727532,14727720,14727857,14728264,14728373,14728984,14729027,14729028,14729085,14729194,14729216,14729217,14729238,14729239,14729820,14729821,14729838,14730083,14730495,14730674,14731604,14732895,14733125,14733131,14733523,14733800,14734027,14734928,14736730,14737139,14738431,14738596,14738976,14739108,14739287,14739323,14739835,14740550,14740964,14740976,14741139,14741449,14742606,14742874,14743604,14743956,14744509,14744781,14745082,14745910,14745989,14746031,14746398,14747228,16952782,16952810,17385674,17385854,17385949,17386289,17386390,17386515,17387367,17387597,17401132,17401239,17401730,17401828,17402821,17402822,17402824,17402997,17403351,17403439,17406747,17406848,17407253,17408053,17408241,17408270,17408422,17408817,17409264,17409304,17409307,17409738,17410353,17410547,17410587,17410787,17410967,17411171,17411386,17411414,17411483,17411507,17411802,17412068,17412603,17412688,17413055,17413089,17413265,17413398,17414224,17414362,17414371,17414631,17414727,17414812,17414865,17414866,17415112,17415216,17415359,17416128,17416287
# <Response [200]>
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# ~/thenv/lib/python3.8/site-packages/requests/models.py in json(self, **kwargs)
#     970         try:
# --> 971             return complexjson.loads(self.text, **kwargs)
#     972         except JSONDecodeError as e:
#
# ~/thenv/lib/python3.8/site-packages/simplejson/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, use_decimal, allow_nan, **kw)
#     513             and not use_decimal and not allow_nan and not kw):
# --> 514         return _default_decoder.decode(s)
#     515     if cls is None:
#
# ~/thenv/lib/python3.8/site-packages/simplejson/decoder.py in decode(self, s, _w, _PY3)
#     388         if end != len(s):
# --> 389             raise JSONDecodeError("Extra data", s, end, len(s))
#     390         return obj
#
# JSONDecodeError: Extra data: line 1 column 6 - line 96891 column 1 (char 5 - 18601028)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-145-7d2a39cf6f91> in <module>
#      13 r = requests.get('https://pubchem.ncbi.nlm.nih.gov/rest/pug/assay/aid/' + str(736) + '/concise/CSV?sid=' + active_736_formatted)
#      14 print(r)
# ---> 15 dose_response = r.json()
#      16 print(dose_response)
#
# ~/thenv/lib/python3.8/site-packages/requests/models.py in json(self, **kwargs)
#     973             # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974             # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975             raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#     976
#     977     @property
#
# JSONDecodeError: Extra data: line 1 column 6 (char 5)

# %%
# Out:
# <class 'str'>

# %%
r = requests.get('https://pubchem.ncbi.nlm.nih.gov/assay/pcget.cgi?query=download&record_type=datatable&actvty=active&response_type=display&aid=1811724')
loose_data = r.text


listed_data = loose_data.split(',')

cid_index = listed_data.index("PUBCHEM_CID")
#print(cid_index)
#print(type(cid_index))

activity_index = listed_data.index("PUBCHEM_ACTIVITY_SCORE")
#print(activity_index)
#print(type(activity_index))

fhand = io.StringIO(loose_data)

cids_with_activities = []

for line in fhand:
    line = line.split(',')
    
    while ('' in line):
        line.remove('')
    try:
        int(line[0])
    except:
        line = ""
        continue
    cid_with_activity = (line[cid_index], line[activity_index])
    cids_with_activities.append(cid_with_activity)
print(cids_with_activities)
# Out:
# [('117951478', '0.0675'), ('150469088', '0.0118'), ('166625340', '0.0078'), ('153532996', '0.0179'), ('166626037', '0.013'), ('166626145', '0.0556'), ('156807419', '0.0027'), ('166626497', '0.00359'), ('153533003', '0.0564'), ('166626654', '0.0452'), ('153532989', '0.0712'), ('166626825', '0.0148'), ('166626832', '0.0227'), ('166627038', '0.0267'), ('149610749', '0.0921'), ('153532988', '0.0121'), ('166628251', '0.00811'), ('166628702', '0.0155'), ('166628766', '0.0124'), ('153533002', '0.00477'), ('153532985', '0.0494'), ('156807421', '0.0618'), ('156807422', '0.0277'), ('166629498', '0.0178'), ('149687113', '0.0874'), ('166630179', '0.00565'), ('153533001', '0.0377'), ('149728083', '0.0467'), ('150544999', '0.0102'), ('166631838', '0.00801'), ('166632237', '0.0732'), ('153532993', '0.0209'), ('153532990', '0.00998'), ('151450990', '0.00744'), ('166632690', '0.0127'), ('166632769', '0.061'), ('150565018', '0.00878'), ('166632937', '0.0214'), ('149687313', '0.00891'), ('156807418', '0.00875'), ('166633613', '0.00431'), ('166633639', '0.353'), ('153532999', '0.0823'), ('151608912', '0.0287'), ('118435096', '0.0302'), ('150495629', '0.0395'), ('166635039', '0.0102'), ('153533000', '0.00933'), ('152464612', '0.0131'), ('153532984', '0.0557')]
